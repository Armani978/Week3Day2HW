# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
url = 'https://ergast.com/api/f1/2008/5/driverStandings.json'

# %%
#response object
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
print(response.json())
print(type(response.json()))
# Out:
# {'abilities': [{'ability': {'name': 'multitype', 'url': 'https://pokeapi.co/api/v2/ability/121/'}, 'is_hidden': False, 'slot': 1}], 'base_experience': 324, 'forms': [{'name': 'arceus-normal', 'url': 'https://pokeapi.co/api/v2/pokemon-form/493/'}, {'name': 'arceus-bug', 'url': 'https://pokeapi.co/api/v2/pokemon-form/10041/'}, {'name': 'arceus-dark', 'url': 'https://pokeapi.co/api/v2/pokemon-form/10042/'}, {'name': 'arceus-dragon', 'url': 'https://pokeapi.co/api/v2/pokemon-form/10043/'}, {'name': 'arceus-electric', 'url': 'https://pokeapi.co/api/v2/pokemon-form/10044/'}, {'name': 'arceus-fighting', 'url': 'https://pokeapi.co/api/v2/pokemon-form/10045/'}, {'name': 'arceus-fire', 'url': 'https://pokeapi.co/api/v2/pokemon-form/10046/'}, {'name': 'arceus-flying', 'url': 'https://pokeapi.co/api/v2/pokemon-form/10047/'}, {'name': 'arceus-ghost', 'url': 'https://pokeapi.co/api/v2/pokemon-form/10048/'}, {'name': 'arceus-grass', 'url': 'https://pokeapi.co/api/v2/pokemon-form/10049/'}, {'name': 
# ...

# %%
# We only want the Driver Standings
data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']
print(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/7v/260_j5h924q5c4dmbl58pd340000gn/T/ipykernel_57753/3923847875.py in <module>
#       1 # We only want the Driver Standings
# ----> 2 data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']
#       3 print(data)
#
# KeyError: 'MRData'

# %%
type(data)
# Out:
# list

# %%
data[0]
# Out:
# {'position': '1',
#  'positionText': '1',
#  'points': '35',
#  'wins': '2',
#  'Driver': {'driverId': 'raikkonen',
#   'permanentNumber': '7',
#   'code': 'RAI',
#   'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#   'givenName': 'Kimi',
#   'familyName': 'Räikkönen',
#   'dateOfBirth': '1979-10-17',
#   'nationality': 'Finnish'},
#  'Constructors': [{'constructorId': 'ferrari',
#    'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#    'name': 'Ferrari',
#    'nationality': 'Italian'}]}

# %%
def get_racer_info(data):
    new_data = []
    for racer in data:
        racer_dict={}
        racer_name = f"{racer['Driver']['givenName']} {racer['Driver']['familyName']}"
        racer_dict[racer_name]={
            "last_name":racer['Driver']['familyName'],
            "first_name":racer['Driver']['givenName'],
            "position":racer['position'],
            "wins":racer['wins'],
            "DOB":racer['Driver']['dateOfBirth'],
            "nationality":racer['Driver']['nationality'],
            "constructor":racer['Constructors'][0]['name']
        }
        new_data.append(racer_dict)
    return new_data

print(get_racer_info(data))
# Out:
# [{'Kimi Räikkönen': {'last_name': 'Räikkönen', 'first_name': 'Kimi', 'position': '1', 'wins': '2', 'DOB': '1979-10-17', 'nationality': 'Finnish', 'constructor': 'Ferrari'}}, {'Felipe Massa': {'last_name': 'Massa', 'first_name': 'Felipe', 'position': '2', 'wins': '2', 'DOB': '1981-04-25', 'nationality': 'Brazilian', 'constructor': 'Ferrari'}}, {'Lewis Hamilton': {'last_name': 'Hamilton', 'first_name': 'Lewis', 'position': '3', 'wins': '1', 'DOB': '1985-01-07', 'nationality': 'British', 'constructor': 'McLaren'}}, {'Robert Kubica': {'last_name': 'Kubica', 'first_name': 'Robert', 'position': '4', 'wins': '0', 'DOB': '1984-12-07', 'nationality': 'Polish', 'constructor': 'BMW Sauber'}}, {'Nick Heidfeld': {'last_name': 'Heidfeld', 'first_name': 'Nick', 'position': '5', 'wins': '0', 'DOB': '1977-05-10', 'nationality': 'German', 'constructor': 'BMW Sauber'}}, {'Heikki Kovalainen': {'last_name': 'Kovalainen', 'first_name': 'Heikki', 'position': '6', 'wins': '0', 'DOB': '1981-10-19', 'national
# ...

# %%
def get_driver_info_by_year_and_round(year, r):
    url = f'https://ergast.com/api/f1/{year}/{r}/driverStandings.json'
    response = requests.get(url)
    if not response.ok:
        return'We had an error'
    if not response.json(['MrData']['StandingsTable']['StandingsLists']):
        return " We had an error loading your data most likely because the year/combo is not in the database"
# Out:
# <>:6: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:6: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# /var/folders/7v/260_j5h924q5c4dmbl58pd340000gn/T/ipykernel_57753/3987425234.py:6: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   if not response.json(['MrData']['StandingsTable']['StandingsLists']):

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny', attack base_state, hp base_stat, defense base_stat

# %%
# Do Not Loop Over Data, just index through info

import requests
# ARCEUS 
url = 'https://pokeapi.co/api/v2/pokemon/arceus'
response = requests.get(url)
#name
name = response.json()['name']
print("My pokemon's name is: " + name)
#one ability name
ability = response.json()['abilities'][0]['ability']['name']
print("Ability is : "+ability)
#base experience
base_experience = response.json()['base_experience']
print(base_experience)

####### URL Sprite

#front_shiny

front_shiny = response.json()['sprites']['front_shiny']
print(front_shiny)

#attack base_stat
attack_base_stat = response.json()['stats'][1]['base_stat']
print(attack_base_stat)

#hp base stat
hp_base_stat = response.json()['stats'][0]['base_stat']
print(hp_base_stat)

#defense base-stat
defense_base_stat = response.json()['stats'][2]['base_stat']
print(defense_base_stat)

# KYUREM
url = 'https://pokeapi.co/api/v2/pokemon/kyurem'
response = requests.get(url)
#name
name = response.json()['name']
print("My pokemon's name is: " + name)
#one ability name
ability = response.json()['abilities'][0]['ability']['name']
print("Ability is : "+ability)
#base experience
base_experience = response.json()['base_experience']
print(base_experience)

####### URL Sprite

#front_shiny

front_shiny = response.json()['sprites']['front_shiny']
print(front_shiny)

#attack base_stat
attack_base_stat = response.json()['stats'][1]['base_stat']
print(attack_base_stat)

#hp base stat
hp_base_stat = response.json()['stats'][0]['base_stat']
print(hp_base_stat)

#defense base-stat
defense_base_stat = response.json()['stats'][2]['base_stat']
print(defense_base_stat)

# Zacian
url = 'https://pokeapi.co/api/v2/pokemon/zacian'
response = requests.get(url)
#name
name = response.json()['name']
print("My pokemon's name is: " + name)
#one ability name
ability = response.json()['abilities'][0]['ability']['name']
print("Ability is : "+ ability)
#base experience
base_experience = response.json()['base_experience']
print(base_experience)

####### URL Sprite

#front_shiny

front_shiny = response.json()['sprites']['front_shiny']
print(front_shiny)

#attack base_stat
attack_base_stat = response.json()['stats'][1]['base_stat']
print(attack_base_stat)

#hp base stat
hp_base_stat = response.json()['stats'][0]['base_stat']
print(hp_base_stat)

#defense base-stat
defense_base_stat = response.json()['stats'][2]['base_stat']
print(defense_base_stat)

# ZAMAZENTA
url = 'https://pokeapi.co/api/v2/pokemon/zamazenta'
response = requests.get(url)
#name
name = response.json()['name']
print("My pokemon's name is: " + name)
#one ability name
ability = response.json()['abilities'][0]['ability']['name']
print("Ability is : "+ability)
#base experience
base_experience = response.json()['base_experience']
print(base_experience)

####### URL Sprite

#front_shiny

front_shiny = response.json()['sprites']['front_shiny']
print(front_shiny)

#attack base_stat
attack_base_stat = response.json()['stats'][1]['base_stat']
print(attack_base_stat)

#hp base stat
hp_base_stat = response.json()['stats'][0]['base_stat']
print(hp_base_stat)

#defense base-stat
defense_base_stat = response.json()['stats'][2]['base_stat']
print(defense_base_stat)

# MEWTWO
url = 'https://pokeapi.co/api/v2/pokemon/mewtwo'
response = requests.get(url)
#name
name = response.json()['name']
print("My pokemon's name is: " + name)
#one ability name
ability = response.json()['abilities'][0]['ability']['name']
print("Ability is : "+ ability)
#base experience
base_experience = response.json()['base_experience']
print(base_experience)

####### URL Sprite

#front_shiny

front_shiny = response.json()['sprites']['front_shiny']
print(front_shiny)

#attack base_stat
attack_base_stat = response.json()['stats'][1]['base_stat']
print(attack_base_stat)

#hp base stat
hp_base_stat = response.json()['stats'][0]['base_stat']
print(hp_base_stat)

#defense base-stat
defense_base_stat = response.json()['stats'][2]['base_stat']
print(defense_base_stat)
# Out:
# My pokemon's name is: arceus
# Ability is : multitype
# 324
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/493.png
# 120
# 120
# 120
# My pokemon's name is: kyurem
# Ability is : pressure
# 330
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/646.png
# 130
# 125
# 90
# My pokemon's name is: zacian
# Ability is : intrepid-sword
# 335
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/888.png
# 130
# 92
# 115
# My pokemon's name is: zamazenta
# Ability is : dauntless-shield
# 335
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/889.png
# 130
# 92
# 115
# My pokemon's name is: mewtwo
# Ability is : pressure
# 340
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/150.png
# 110
# 106
# 90
